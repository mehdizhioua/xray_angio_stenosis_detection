# %%
import os
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from PIL import Image
import numpy as np
import xml.etree.ElementTree as ET
from Model import StenosisDetector
from AngioDataset import MyDataset
from utils import *
import torchvision

# %%
img_dir = 'sample_data/image_dir'
xml_dir = 'sample_data/xml_dir'
dataset = MyDataset(img_dir=img_dir, xml_dir=xml_dir)
angio_data = torch.utils.data.DataLoader(dataset,batch_size=2)
# (xmin, xmax, ymin, ymax)

print(dataset[1][1].shape)
# Out:
# (512, 512, 3)

# %%
i = 1
plt.figure(figsize=(10,10))
#xmin = dataset[i][2][0][2]
#xmax = dataset[i][2][0][3]
#ymin = dataset[i][2][0][0]
#ymax = dataset[i][2][0][1]
plt.imshow(dataset[i][1])
#plt.plot([xmin, xmin], [ymin, ymax], c='g', linewidth=1)
#plt.plot([xmin, xmax], [ymin, ymin], c='g', linewidth=1)
#plt.plot([xmax, xmax], [ymin, ymax], c='g', linewidth=1)
#plt.plot([xmin, xmax], [ymax, ymax], c='g', linewidth=1)
